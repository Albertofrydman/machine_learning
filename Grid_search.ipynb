# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

# %%
diabetes=load_diabetes(as_frame=True,scaled=False)
X=diabetes.data
y=diabetes.target

# %%
diabetes["target"]
#diabetes.keys()
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: target, Length: 442, dtype: float64

# %%
SEED = 42
np.random.seed(SEED)

# %%
KNN = KNeighborsRegressor()
KNN.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %%
diabetes=load_diabetes()
param_grid = {
"n_neighbors" : [5,10],
"weights" : ["uniform", "distance"],
"algorithm" : ["auto", "ball_tree", "kd_tree"]
}

KNN = KNeighborsRegressor()

clf = GridSearchCV(KNN, param_grid,refit="neg_mean_squared_error",cv=3,scoring = ["neg_mean_squared_error","neg_root_mean_squared_error"])
clf.fit(diabetes.data, diabetes.target)
print(sorted(clf.cv_results_.keys()))

#Imprime los mejores parametros
"""print(clf.best_estimator_)
print(clf.best_score_)
print(clf.best_params_)
#print(clf.scorer_)"""

# Predecir con el mejor modelo
"""mejor_modelo = clf.best_estimator_
predicciones = mejor_modelo.predict(X)
predicciones"""

#GridSearchCV(KNN, param_grid,refit="neg_mean_squared_error",cv=3,scoring = ["neg_mean_squared_error","neg_root_mean_squared_error"])
#GridSearchCV(KNN, param_grid,refit="neg_root_mean_squared_error",cv=3,scoring = ["neg_mean_squared_error","neg_root_mean_squared_error"])

#GridSearchCV(KNN, param_grid,refit=True,cv=3)
# Out:
# ['mean_fit_time', 'mean_score_time', 'mean_test_neg_mean_squared_error', 'mean_test_neg_root_mean_squared_error', 'param_algorithm', 'param_n_neighbors', 'param_weights', 'params', 'rank_test_neg_mean_squared_error', 'rank_test_neg_root_mean_squared_error', 'split0_test_neg_mean_squared_error', 'split0_test_neg_root_mean_squared_error', 'split1_test_neg_mean_squared_error', 'split1_test_neg_root_mean_squared_error', 'split2_test_neg_mean_squared_error', 'split2_test_neg_root_mean_squared_error', 'std_fit_time', 'std_score_time', 'std_test_neg_mean_squared_error', 'std_test_neg_root_mean_squared_error']
# 'mejor_modelo = clf.best_estimator_\npredicciones = mejor_modelo.predict(X)\npredicciones'

# %%
# Predecir con el mejor modelo
mejor_modelo = clf.best_estimator_
predicciones = mejor_modelo.predict(X)
#predicciones
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but KNeighborsRegressor was fitted without feature names
#   warnings.warn(

# %%
resultados = clf.cv_results_
df = pd.DataFrame(resultados)
df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.007914      0.002948         0.015169        0.002583
# 1        0.004753      0.003960         0.012612        0.003566
# 2        0.001510      0.000080         0.009461        0.003890
# 3        0.002523      0.001632         0.011091        0.003412
# 4        0.003406      0.002852         0.014070        0.005899
# 5        0.003673      0.002636         0.015479        0.004732
# 6        0.003840      0.001917         0.025729        0.004483
# 7        0.007027      0.001015         0.016080        0.004518
# 8        0.004634      0.000837         0.016323        0.006220
# 9        0.004402      0.004305         0.016296        0.002966
# 10       0.007735      0.005609         0.012463        0.000537
# 11       0.003262      0.001423         0.011077        0.004338
#
#    param_algorithm  param_n_neighbors param_weights  \
# 0             auto                  5       uniform
# ...

# %%
print(clf.best_estimator_)
print(clf.best_score_)
print(clf.best_params_)
# Out:
# KNeighborsRegressor(n_neighbors=10, weights='distance')
# -3216.4316212100553
# {'algorithm': 'auto', 'n_neighbors': 10, 'weights': 'distance'}

# %%
clf.get_params
# Out:
# <bound method BaseEstimator.get_params of GridSearchCV(cv=3, estimator=KNeighborsRegressor(),
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree'],
#                          'n_neighbors': [5, 10],
#                          'weights': ['uniform', 'distance']},
#              refit='neg_mean_squared_error',
#              scoring=['neg_mean_squared_error', 'neg_root_mean_squared_error'])>
