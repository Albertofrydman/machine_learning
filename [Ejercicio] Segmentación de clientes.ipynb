# %% [markdown]
# # Segmentación de clientes

# %% [markdown]
# La segmentación de clientes es el proceso de dividir a los clientes en grupos según características comunes para que las empresas puedan comercializar sus productos y servicios con cada grupo de manera eficaz y adecuada.
#
# ## Tareas
#
# En este ejercicio usará el siguiente dataset: [Online Retail](https://archive.ics.uci.edu/dataset/352/online+retail)
#
# 1. Realizar la limpieza y el análisis exploratorio de datos
# 2. Responder las siguientes preguntas usando dataframes y visualizaciones:
#   - ¿Cuál es el número promedio de pedidos por cliente?
#   - ¿Quiénes fueron los mejores clientes a lo largo del año? Considerar el monto de compra de los clientes.
#   - ¿Cuál es el total de ventas mensual del año 2011?
#   - ¿Cuál es el mes y días de la semana con mayor actividad? Considerar el precio total de ventas.
# 3. Preprocesar los datos
# 4. Aplicar algoritmos de clustering:
#   - K-Means, Mini-batch K-Means: Identificar el número óptimo de clusters usando el método de codo y silueta. Realizar visualizaciones. Puede usar la librería [yellowbrick](https://www.scikit-yb.org/en/latest/api/cluster/index.html).
#   - Aglomerativo: Identificar el número de clusters usando dendrogramas. Puede usar la librería [scipy](https://docs.scipy.org/doc/scipy/reference/generated/scipy.cluster.hierarchy.dendrogram.html#scipy.cluster.hierarchy.dendrogram).
#   - DBSCAN: Investigar sobre la gráfica de distancias (k-distance plot/distancia al k-ésimo vecino más cercano) para determinar el mejor valor de hiperparámetros.
# 5. Para todos los algoritmos de clustering visualizar los resultados usando PCA o T-SNE en 2d y 3d.
# 6. Agregar los asignaciones obtenidas por el mejor algoritmo de clustering a cada muestra del dataframe (agregar una columna nueva) y analize los resultados de los agrupamientos obtenidos. ¿Qué características tienen los clientes de los clusters obtenidos? Puede realizar visualizaciones para ayudar a explicar lo que pudo encontrar.
# 7. RFM:
#   - Investigar sobre RFM (Recency, Frequency, and Monetary)
#   - Obtener los valores de RFM para cada cliente en el dataframe (Agregar tres columnas)
#   - Asignar scores a los valores de RFM obtenidos
#   - Aplicar los puntos desde el 3 al 6 sobre estas variables obtenidas.
