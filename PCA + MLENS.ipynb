# %% [markdown]
# # Implementar PCA usando numpy (opcional)

# %%
class PCA:
    def __init__(self, n_components):
        self.n_components = n_components
        self.components = None
        self.explained_variance = None
        self.explained_variance_ratio = None
        self.mean = None

    def fit(self, X):
        pass

    def transform(self, X):
        pass

    def fit_transform(self, X):
        pass

# %% [markdown]
# # Librería de Mlens
#
# http://ml-ensemble.com/

# %%
# !pip install -U mlens

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
from mlens.ensemble import SuperLearner

# %% [markdown]
# Al ejecutar la celda anterior saltará un error, presionar en último enlace del error, esto abrirá el código fuente que se puede editar. Cambiar el código de ``from collections import Sequence`` a ``from collections.abc import Sequence``. Luego ejecutar la siguiente celda que actualiza el código en la sesión actual.

# %%
import imp
import mlens
imp.reload(mlens)

# %%
import numpy as np
from pandas import DataFrame
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris

seed = 2017
np.random.seed(seed)

data = load_iris()
idx = np.random.permutation(150)
X = data.data[idx]
y = data.target[idx]

# %%
from mlens.ensemble import SuperLearner
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# --- Build ---
# Passing a scoring function will create cv scores during fitting
# the scorer should be a simple function accepting to vectors and returning a scalar
ensemble = SuperLearner(scorer=accuracy_score, random_state=seed, verbose=2)

# Build the first layer
ensemble.add([RandomForestClassifier(random_state=seed), SVC()])

# Attach the final meta estimator
ensemble.add_meta(LogisticRegression())

# --- Use ---

# Fit ensemble
ensemble.fit(X[:75], y[:75])

# Predict
preds = ensemble.predict(X[75:])
# Out:
# Fitting 2 layers
# Processing layer-1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-b9adf360fc97> in <cell line: 20>()
#      18
#      19 # Fit ensemble
# ---> 20 ensemble.fit(X[:75], y[:75])
#      21
#      22 # Predict
#
# /usr/local/lib/python3.10/dist-packages/mlens/ensemble/base.py in fit(self, X, y, **kwargs)
#     512             self._id_train.fit(X)
#     513
# --> 514         out = self._backend.fit(X, y, **kwargs)
#     515         if out is not self._backend:
#     516             # fit_transform
#
# /usr/local/lib/python3.10/dist-packages/mlens/ensemble/base.py in fit(self, X, y, **kwargs)
#     156         with ParallelProcessing(self.backend, self.n_jobs,
#     157                                 max(self.verbose - 4, 0)) as manager:
# --> 158             out = manager.stack(self, 'fit', X, y, **kwargs)
#     159
# ...
